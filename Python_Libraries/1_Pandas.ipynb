# %%
import pandas as pd

# %%
"""
Files :
    sample csv file - https://github.com/codeforamerica/ohana-api/tree/master/data/sample-csv
    Titanic - https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
    excel file - https://github.com/finbourne/sample-excel
"""
# Out:
# '\nFiles :\n    sample csv file - https://github.com/codeforamerica/ohana-api/tree/master/data/sample-csv\n    Titanic - https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv\n    excel file - https://github.com/finbourne/sample-excel\n'

# %%
 import pandas as pd
 import json

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html', flavor='html5lib')

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
dtype = df1.dtypes

# %%
dtype
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
print(dtype)
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1.to_csv('NBA.csv')

# %%
df1.to_csv('NBA1.csv', index=False)

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 1

# %%
l[0]
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
# 2            S Aravind  2015-2015    1    -   0     -    -      -    0.00   -
# 3       Arshdeep Singh  2022-2023   33    8   6    32   12  16.00  133.33   -
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
# ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
# 102      R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
# 103  Washington Sundar  2017-2023   37   15   5   107   50  10.70  150.70   -
# 104           SA Yadav  2021-2023   53   50  10  1841  117  46.02  172.70   3
# 105           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
# 106       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#      50  0
# 0     -  -
# 1     -  -
# 2     -  -
# 3     -  -
# 4     -  -
# ..   .. ..
# 102   -  -
# 103   1  4
# 104  15  3
# 105   -  -
# 106   8  1
#
# [107 rows x 12 columns]

# %%
l[0].to_csv('cricket.csv', index=False)

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1745/2567112034.py in ?()
# ----> 1 pd.DataFrame(d)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     813                 )
#     814         # For data is scalar
#     815         else:
#     816             if index is None or columns is None:
# --> 817                 raise ValueError("DataFrame constructor not properly called!")
#     818
#     819             index = ensure_index(index)
#     820             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
import json

# %%
json.loads(d)
# Out:
# {'name': 'Sudhanshu kumar',
#  'email id ': 'sskumar@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
result = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
r = pd.DataFrame(result)

# %%
r
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
type(df1[['Age','GS']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1.to_csv('NBA.csv')

# %%
df1[['Age','GS']].to_csv('NBA1.csv')

# %%
df1.to_csv('NBA2.csv', index=False)

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 1

# %%
l[0]
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
# 2            S Aravind  2015-2015    1    -   0     -    -      -    0.00   -
# 3       Arshdeep Singh  2022-2023   33    8   6    32   12  16.00  133.33   -
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
# ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
# 102      R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
# 103  Washington Sundar  2017-2023   37   15   5   107   50  10.70  150.70   -
# 104           SA Yadav  2021-2023   53   50  10  1841  117  46.02  172.70   3
# 105           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
# 106       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#      50  0
# 0     -  -
# 1     -  -
# 2     -  -
# 3     -  -
# 4     -  -
# ..   .. ..
# 102   -  -
# 103   1  4
# 104  15  3
# 105   -  -
# 106   8  1
#
# [107 rows x 12 columns]

# %%
l[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 l[1]
#
# IndexError: list index out of range

# %%
l[0].to_csv('cricket.csv', index=False)

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result  = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result['name']
# Out:
# 'Sudhanshu kumar'

# %%
result
# Out:
# {'name': 'Sudhanshu kumar',
#  'email id ': 'sskumar@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
pd.DataFrame(result)
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
pd.read_json(d)
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
type(d)
# Out:
# str

# %%
result['name']
# Out:
# 'Sudhanshu kumar'

# %%
result['tech']
# Out:
# ['ML', 'DL', 'CV']

# %%
type(result['tech'])
# Out:
# list

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
pd.DataFrame(d['data'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.DataFrame(d['data'])
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
d1=d['data']

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
#url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/55343  1920537722
# 1     https://github.com/pandas-dev/pandas/pull/55342  1920499550
# 2     https://github.com/pandas-dev/pandas/pull/55341  1920420532
# 3     https://github.com/pandas-dev/pandas/pull/55340  1920384934
# 4     https://github.com/pandas-dev/pandas/pull/55338  1920379380
# 5     https://github.com/pandas-dev/pandas/pull/55337  1920358270
# 6   https://github.com/pandas-dev/pandas/issues/55335  1920331171
# 7   https://github.com/pandas-dev/pandas/issues/55334  1920323639
# 8   https://github.com/pandas-dev/pandas/issues/55333  1920323446
# 9   https://github.com/pandas-dev/pandas/issues/55332  1920211451
# 10    https://github.com/pandas-dev/pandas/pull/55331  1920074530
# 11    https://github.com/pandas-dev/pandas/pull/55330  1920068149
# 12    https://github.com/pandas-dev/pandas/pull/55328  1919809303
# 13    https://github.com/pandas-dev/pandas/pull/55327  1919791766
# 14  https://github.com/pandas-dev/pandas/issues/55326  1919743019
# 15    https://github.com/pandas-dev/pandas/pull/55324  1919280333
# 16  https://github.com/pandas-dev/pandas/issues/55323  1919231201
# 17  https://github.com/pandas-dev/pandas/issues/55322  1918764430
# 18  https://github.com/pandas-dev/pandas/issues/55321  1918395993
# 19    https://github.com/pandas-dev/pandas/pull/55319  1918304478
# 20  https://github.com/pandas-dev/pandas/issues/55318  1918267298
# 21  https://github.com/pandas-dev/pandas/issues/55317  1918123086
# 22    https://github.com/pandas-dev/pandas/pull/55314  1917166813
# 23    https://github.com/pandas-dev/pandas/pull/55312  1916404719
# 24  https://github.com/pandas-dev/pandas/issues/55311  1916284224
# 25    https://github.com/pandas-dev/pandas/pull/55309  1916145296
# 26  https://github.com/pandas-dev/pandas/issues/55308  1915910535
# 27    https://github.com/pandas-dev/pandas/pull/55306  1915636748
# 28  https://github.com/pandas-dev/pandas/issues/55305  1914754229
# 29    https://github.com/pandas-dev/pandas/pull/55304  1914609861
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85yeRR6   55343
# 1   PR_kwDOAA0YD85bmZvc   55342
# 2   PR_kwDOAA0YD85bmJBE   55341
# 3   PR_kwDOAA0YD85bmCaO   55340
# 4   PR_kwDOAA0YD85bmBV6   55338
# 5   PR_kwDOAA0YD85bl9SM   55337
# 6    I_kwDOAA0YD85yde2j   55335
# 7    I_kwDOAA0YD85yddA3   55334
# 8    I_kwDOAA0YD85ydc92   55333
# 9    I_kwDOAA0YD85ydBn7   55332
# 10  PR_kwDOAA0YD85blF_L   55331
# 11  PR_kwDOAA0YD85blEvW   55330
# 12  PR_kwDOAA0YD85bkNDx   55328
# 13  PR_kwDOAA0YD85bkJRR   55327
# 14   I_kwDOAA0YD85ybPQr   55326
# 15  PR_kwDOAA0YD85bibqJ   55324
# 16   I_kwDOAA0YD85yZSTh   55323
# 17   I_kwDOAA0YD85yXgWO   55322
# 18   I_kwDOAA0YD85yWGZZ   55321
# 19  PR_kwDOAA0YD85bfH5n   55319
# 20   I_kwDOAA0YD85yVm-i   55318
# 21   I_kwDOAA0YD85yVDxO   55317
# 22  PR_kwDOAA0YD85bbM_h   55314
# 23  PR_kwDOAA0YD85bYoMB   55312
# 24   I_kwDOAA0YD85yOC1A   55311
# 25  PR_kwDOAA0YD85bXu0N   55309
# 26   I_kwDOAA0YD85yMnmH   55308
# 27  PR_kwDOAA0YD85bWAQU   55306
# 28   I_kwDOAA0YD85yINS1   55305
# 29  PR_kwDOAA0YD85bSj5Z   55304
#
#                                                 title  ... closed_at  \
# 0   BUG: roll_std compute different result when in...  ...       NaT
# 1     REF: check monotonicity inside _can_use_libjoin  ...       NaT
# 2        ENH: Implement convert_dtypes on block level  ...       NaT
# 3                 Implement masked algorithm for mode  ...       NaT
# 4   Raises a ValueError for not handled dtypes in ...  ...       NaT
# 5                 DOC: Adjust user guide for CoW docs  ...       NaT
# 6   BUG/TST: can_use_libjoin exclude CategoricalDt...  ...       NaT
# 7   BUG: groupby(as_index=True).nth() does not ret...  ...       NaT
# 8   BUG/TST: can_use_libjoin cases with mixed-freq...  ...       NaT
# 9   BUG: DataFrame Interchange Protocol errors on ...  ...       NaT
# 10                      BLD: Fix gitpod meson version  ...       NaT
# 11                            TYP: read_csv's usecols  ...       NaT
# 12  DOC: add parameters and examples to CustomBusi...  ...       NaT
# 13           COMPAT: Fix warning with numba >= 0.58.0  ...       NaT
# 14  BUG: groupby.transform with a reducer and unob...  ...       NaT
# 15  BUG: fix parsing of ODF time values with comments  ...       NaT
# 16  ENH: Add list accessor for PyArrow list types ...  ...       NaT
# 17  BUG: problem with dt.hour/second/etc with time...  ...       NaT
# 18  BUG: to_datetime drops decimal point and fract...  ...       NaT
# 19  BUG: `date_range` `inclusive` parameter behavi...  ...       NaT
# 20        DOC: Update contributing docs on git bisect  ...       NaT
# 21  BUG: FutureWarning when creating column of tz ...  ...       NaT
# 22        ENH: propagating attrs always uses deepcopy  ...       NaT
# 23                     REF: Add tests.groupby.methods  ...       NaT
# 24                          DOC: Issue triage updates  ...       NaT
# 25        DOC move resample bug whatsnew notes to 2.2  ...       NaT
# 26            BUG: Indexing by frozendict not allowed  ...       NaT
# 27                            ENH: case_when function  ...       NaT
# 28  BUG: ValueError: Buffer dtype mismatch, expect...  ...       NaT
# 29                 Valid capitalization errors #32550  ...       NaT
#
#    author_association active_lock_reason  \
# 0                NONE                NaN
# 1              MEMBER                NaN
# 2              MEMBER                NaN
# 3              MEMBER                NaN
# 4         CONTRIBUTOR                NaN
# 5              MEMBER                NaN
# 6              MEMBER                NaN
# 7         CONTRIBUTOR                NaN
# 8              MEMBER                NaN
# 9         CONTRIBUTOR                NaN
# 10        CONTRIBUTOR                NaN
# 11        CONTRIBUTOR                NaN
# 12        CONTRIBUTOR                NaN
# 13             MEMBER                NaN
# 14             MEMBER                NaN
# 15               NONE                NaN
# 16        CONTRIBUTOR                NaN
# 17               NONE                NaN
# 18               NONE                NaN
# 19               NONE                NaN
# 20             MEMBER                NaN
# 21               NONE                NaN
# 22        CONTRIBUTOR                NaN
# 23             MEMBER                NaN
# 24             MEMBER                NaN
# 25             MEMBER                NaN
# 26        CONTRIBUTOR                NaN
# 27               NONE                NaN
# 28               NONE                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   ### Pandas version checks\r\n\r\n- [X] I have ...
# 1   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 2   The current implementation is pretty bad in th...
# 3   - [ ] closes #45776 (Replace xxxx with the Git...
# 4   Raises a ValueError in PandasColumn._dtype_fro...
# 5   This is mostly from my blog post, would like t...
# 6   In several `Index` methods we have libjoin fas...
# 7   ### Pandas version checks\n\n- [X] I have chec...
# 8   In the Index code we have a fastpaths in for _...
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  - [X] closes #55214 \r\n- [X] All [code checks...
# 11  This makes read_csv's usecols compatible with ...
# 12  In the documentation of offsets classes: [Cust...
# 13  - [ ] closes #55247 (Replace xxxx with the Git...
# 14  The implementation of groupby.transform with a...
# 15  - [x] Fix: #55200 variant for `time-value` cel...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  ### Pandas version checks\r\n\r\n- [X] I have ...
# 18  ### Pandas version checks\r\n\r\n- [X] I have ...
# 19  - [X] closes #55293 \r\n- [X] closes #46331\r\...
# 20  Ref: https://github.com/pandas-dev/pandas/issu...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  Always using a deepcopy prevents shared state ...
# 23  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 24  Documentation: https://pandas.pydata.org/panda...
# 25  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 26  ### Pandas version checks\r\n\r\n- [X] I have ...
# 27  - [x] closes #39154 \r\n- [x] [Tests added and...
# 28  ### Pandas version checks\n\n- [X] I have chec...
# 29  - [x] Fix capitalization at [Fix capitalizatio...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   0.0
# 2                       NaN           NaN   0.0
# 3                       NaN           NaN   0.0
# 4                       NaN           NaN   0.0
# 5                       NaN           NaN   0.0
# 6                       NaN           NaN   NaN
# 7                       NaN           NaN   NaN
# 8                       NaN           NaN   NaN
# 9                       NaN           NaN   NaN
# 10                      NaN           NaN   0.0
# 11                      NaN           NaN   1.0
# 12                      NaN           NaN   0.0
# 13                      NaN           NaN   0.0
# 14                      NaN           NaN   NaN
# 15                      NaN           NaN   0.0
# 16                      NaN           NaN   NaN
# 17                      NaN           NaN   NaN
# 18                      NaN           NaN   NaN
# 19                      NaN           NaN   0.0
# 20                      NaN           NaN   NaN
# 21                      NaN           NaN   NaN
# 22                      NaN           NaN   0.0
# 23                      NaN           NaN   0.0
# 24                      NaN           NaN   NaN
# 25                      NaN           NaN   0.0
# 26                      NaN           NaN   NaN
# 27                      NaN           NaN   0.0
# 28                      NaN           NaN   NaN
# 29                      NaN           NaN   0.0
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20                                                NaN
# 21                                                NaN
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26                                                NaN
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
# [30 rows x 30 columns]

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55343',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55343/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55343/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55343/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55343',
#   'id': 1920537722,
#   'node_id': 'I_kwDOAA0YD85yeRR6',
#   'number': 55343,
#   'title': 'BUG: roll_std compute different result when input same data with diffrent length',
#   'user': {'login': 'qianyun210603',
#    'id': 18441788,
#    'node_id': 'MDQ6VXNlcjE4NDQxNzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18441788?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qianyun210603',
#    'html_url': 'https://github.com/qianyun210603',
#    'followers_url': 'https://api.github.com/users/qianyun210603/followers',
#    'following_url': 'https://api.github.com/users/qianyun210603/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/qianyun210603/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/qianyun210603/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/qianyun210603/subscriptions',
#    'organizations_url': 'https://api.github.com/users/qianyun210603/orgs',
#    'repos_url': 'https://api.github.com/users/qianyun210603/repos',
#    'events_url': 'https://api.github.com/users/qianyun210603/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/qianyun210603/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'PiotrekB416',
#    'id': 89194651,
#    'node_id': 'MDQ6VXNlcjg5MTk0NjUx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89194651?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PiotrekB416',
#    'html_url': 'https://github.com/PiotrekB416',
#    'followers_url': 'https://api.github.com/users/PiotrekB416/followers',
#    'following_url': 'https://api.github.com/users/PiotrekB416/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PiotrekB416/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PiotrekB416/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PiotrekB416/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PiotrekB416/orgs',
#    'repos_url': 'https://api.github.com/users/PiotrekB416/repos',
#    'events_url': 'https://api.github.com/users/PiotrekB416/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PiotrekB416/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'PiotrekB416',
#     'id': 89194651,
#     'node_id': 'MDQ6VXNlcjg5MTk0NjUx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/89194651?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/PiotrekB416',
#     'html_url': 'https://github.com/PiotrekB416',
#     'followers_url': 'https://api.github.com/users/PiotrekB416/followers',
#     'following_url': 'https://api.github.com/users/PiotrekB416/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/PiotrekB416/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/PiotrekB416/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/PiotrekB416/subscriptions',
#     'organizations_url': 'https://api.github.com/users/PiotrekB416/orgs',
#     'repos_url': 'https://api.github.com/users/PiotrekB416/repos',
#     'events_url': 'https://api.github.com/users/PiotrekB416/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/PiotrekB416/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-10-01T03:47:25Z',
#   'updated_at': '2023-10-01T08:14:15Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\n# the data file used in the example https://1drv.ms/u/s!AnPL7Q5hAP8rk1zVitFhPulZWIzP?e=cOae2J (CSV file stored in MS OneDrive)\r\n\r\nimport pandas as pd\r\npd.set_option(\'display.precision\',12)\r\nseries = pd.read_csv(r"E:\\pd_rollingstd_issue.csv", index_col=[0], parse_dates=["date"]).loc[:, \'0\']\r\nseries.loc["2017-05-20":"2017-06-10"]\r\ndate\r\n2017-05-22    10.0242441\r\n2017-05-23    10.0242441\r\n2017-05-24    10.0242441\r\n2017-05-25    10.0242441\r\n2017-05-26    10.0242441\r\n2017-05-31    10.0242441\r\n2017-06-01    10.0242436\r\n2017-06-02    10.0242436\r\n2017-06-05    10.0242436\r\n2017-06-06    10.0242436\r\n2017-06-07    10.0242436\r\n2017-06-08    10.0242436\r\n2017-06-09    10.0242436\r\nName: 0, dtype: float64\r\nseries.loc["2017-05-20":"2017-06-10"].rolling(5).std()\r\ndate\r\n2017-05-22               NaN\r\n2017-05-23               NaN\r\n2017-05-24               NaN\r\n2017-05-25               NaN\r\n2017-05-26    0.000000000000\r\n2017-05-31    0.000000000000\r\n2017-06-01    0.000000223607\r\n2017-06-02    0.000000273861\r\n2017-06-05    0.000000273861\r\n2017-06-06    0.000000223607\r\n2017-06-07    0.000000000000\r\n2017-06-08    0.000000000000\r\n2017-06-09    0.000000000000\r\nName: 0, dtype: float64\r\nseries.rolling(5).std().loc["2017-05-20":"2017-06-10"]\r\ndate\r\n2017-05-22    0.0\r\n2017-05-23    0.0\r\n2017-05-24    0.0\r\n2017-05-25    0.0\r\n2017-05-26    0.0\r\n2017-05-31    0.0\r\n2017-06-01    0.0\r\n2017-06-02    0.0\r\n2017-06-05    0.0\r\n2017-06-06    0.0\r\n2017-06-07    0.0\r\n2017-06-08    0.0\r\n2017-06-09    0.0\r\nName: 0, dtype: float64\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nAs one can see in the example, rolling std with window size 5 generates non-zero number between 2017-06-01 and 2017-06-06 when we use part of the series, which is correct as we see in source series value slightly changes on 2017-06-01. However, when using the whole series, it generates all 0 number, which is not correct.\r\n\r\n\r\n### Expected Behavior\r\n\r\nWith same number in the 5-length window, the whole series should generate same non-zero result for dates between 2017-06-01 and 2017-06-06. \r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : e86ed377639948c64c429059127bcf5b359ab6be\r\npython              : 3.9.16.final.0\r\npython-bits         : 64\r\nOS                  : Windows\r\nOS-release          : 10\r\nVersion             : 10.0.19045\r\nmachine             : AMD64\r\nprocessor           : AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD\r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : None\r\nLOCALE              : English_United States.936\r\n\r\npandas              : 2.1.1\r\nnumpy               : 1.24.2\r\npytz                : 2022.7.1\r\ndateutil            : 2.8.2\r\nsetuptools          : 65.6.3\r\npip                 : 22.3.1\r\nCython              : None\r\npytest              : None\r\nhypothesis          : None\r\nsphinx              : None\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : None\r\nlxml.etree          : 4.9.2\r\nhtml5lib            : None\r\npymysql             : None\r\npsycopg2            : None\r\njinja2              : 3.1.2\r\nIPython             : 8.10.0\r\npandas_datareader   : None\r\nbs4                 : 4.11.2\r\nbottleneck          : None\r\ndataframe-api-compat: None\r\nfastparquet         : None\r\nfsspec               ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55343/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55343/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55342',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55342/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55342/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55342/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55342',
#   'id': 1920499550,
#   'node_id': 'PR_kwDOAA0YD85bmZvc',
#   'number': 55342,
#   'title': 'REF: check monotonicity inside _can_use_libjoin',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-10-01T02:12:53Z',
#   'updated_at': '2023-10-01T02:12:53Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55342',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55342',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55342.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55342.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55342/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55342/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55341',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55341/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55341/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55341/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55341',
#   'id': 1920420532,
#   'node_id': 'PR_kwDOAA0YD85bmJBE',
#   'number': 55341,
#   'title': 'ENH: Implement convert_dtypes on block level',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-30T22:38:29Z',
#   'updated_at': '2023-09-30T23:52:05Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55341',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55341',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55341.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55341.patch',
#    'merged_at': None},
#   'body': "The current implementation is pretty bad in the sense that we will always end up splitting blocks even if we don't want to touch the block at all. Pushing this to the Block level let's us solve that problem.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55341/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55341/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55340',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55340/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55340/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55340/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55340',
#   'id': 1920384934,
#   'node_id': 'PR_kwDOAA0YD85bmCaO',
#   'number': 55340,
#   'title': 'Implement masked algorithm for mode',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-30T20:07:39Z',
#   'updated_at': '2023-09-30T22:39:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55340',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55340',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55340.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55340.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #45776 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55340/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55340/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55338',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55338/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55338/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55338/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55338',
#   'id': 1920379380,
#   'node_id': 'PR_kwDOAA0YD85bmBV6',
#   'number': 55338,
#   'title': 'Raises a ValueError for not handled dtypes in pyarrow Conversion.',
#   'user': {'login': 'paulreece',
#    'id': 96156234,
#    'node_id': 'U_kgDOBbs6Sg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96156234?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulreece',
#    'html_url': 'https://github.com/paulreece',
#    'followers_url': 'https://api.github.com/users/paulreece/followers',
#    'following_url': 'https://api.github.com/users/paulreece/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paulreece/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paulreece/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paulreece/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paulreece/orgs',
#    'repos_url': 'https://api.github.com/users/paulreece/repos',
#    'events_url': 'https://api.github.com/users/paulreece/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paulreece/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-30T19:46:22Z',
#   'updated_at': '2023-09-30T19:56:51Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55338',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55338',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55338.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55338.patch',
#    'merged_at': None},
#   'body': "Raises a ValueError in PandasColumn._dtype_from_pandasdtype for the following unhandled dtypes: 'b', 'B', 'S', 'a', 'V'.\r\n\r\n- [X] closes #55332 (Replace xxxx with the GitHub issue number)\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [X] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55338/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55338/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55337',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55337/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55337/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55337/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55337',
#   'id': 1920358270,
#   'node_id': 'PR_kwDOAA0YD85bl9SM',
#   'number': 55337,
#   'title': 'DOC: Adjust user guide for CoW docs',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-30T18:29:33Z',
#   'updated_at': '2023-09-30T18:29:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55337',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55337',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55337.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55337.patch',
#    'merged_at': None},
#   'body': 'This is mostly from my blog post, would like to backport this ideally.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55337/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55337/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55335',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55335/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55335/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55335/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55335',
#   'id': 1920331171,
#   'node_id': 'I_kwDOAA0YD85yde2j',
#   'number': 55335,
#   'title': 'BUG/TST: can_use_libjoin exclude CategoricalDtype? ',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-30T16:55:54Z',
#   'updated_at': '2023-09-30T19:13:18Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "In several `Index` methods we have libjoin fastpaths and a check `self._can_use_libjoin` to see if we can use it for a given dtype.  The check in Index.join (but not the ones in _union or _intersection) also excludes CategoricalDtype from using the fastpath (and test_join_with_categorical_index breaks if we remove that check).\r\n\r\nI'm _guessing_ that the libjoin fastpaths in `_union` and `_intersection` may also need to exclude CategoricalDtype for the same reason(s) that join does.  The task here is to confirm or disprove, and ensure we have tests that cover the relevant cases.\r\n\r\nIf it turns out that CategoricalDtype (maybe just ordered/unordered or something) should be excluded, then that can be done directly in `_can_use_libjoin`.\r\n\r\nOtherwise, a comment explaining why the join case is different from the others.\r\n\r\nAfterthought possibility: excluding CategoricalDtype in join may only be necessary for `how` that is not inner/outer, in which case the check can be made more precise (with comment as to why)",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55335/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55335/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55334',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55334/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55334/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55334/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55334',
#   'id': 1920323639,
#   'node_id': 'I_kwDOAA0YD85yddA3',
#   'number': 55334,
#   'title': 'BUG: groupby(as_index=True).nth() does not return index values',
#   'user': {'login': 'idealcrouch',
#    'id': 18432229,
#    'node_id': 'MDQ6VXNlcjE4NDMyMjI5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18432229?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idealcrouch',
#    'html_url': 'https://github.com/idealcrouch',
#    'followers_url': 'https://api.github.com/users/idealcrouch/followers',
#    'following_url': 'https://api.github.com/users/idealcrouch/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/idealcrouch/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/idealcrouch/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/idealcrouch/subscriptions',
#    'organizations_url': 'https://api.github.com/users/idealcrouch/orgs',
#    'repos_url': 'https://api.github.com/users/idealcrouch/repos',
#    'events_url': 'https://api.github.com/users/idealcrouch/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/idealcrouch/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2023-09-30T16:31:23Z',
#   'updated_at': '2023-09-30T20:54:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n# data\r\nimport pandas as pd\r\ndf = pd.DataFrame(data={\'order_id\': [\'a1\', \'a1\', \'a2\'], \'size_filled\': [0, 2, 0], \'state\': [\'NEW\', \'FILLED\', \'NEW\']})\r\nprint(df)\r\n\r\n# groupby.first() changes behavior when as_index is True / False, as expected\r\ndf.groupby(\'order_id\', observed=True, as_index=True).first()\r\ndf.groupby(\'order_id\', observed=True, as_index=False).first()\r\n\r\n# however groupby.nth() does NOT change behavior when as_index is True / False\r\ndf.groupby(\'order_id\', observed=True, as_index=True).nth(0)\r\ndf.groupby(\'order_id\', observed=True, as_index=False).nth(0)\n```\n\n\n### Issue Description\n\nIn pandas 2.1.1, when calling groupby.nth(0) in the example, you can see that the index values are not returned. As a sanity check, I verified that groupby(as_index=True).first() behaves as expected.\r\n\r\nI compared this behavior to pandas 1.5.2 and saw groupby(as_index=True).first() and groupby(as_index=True).nth(0) both return the index values as expected. So I believe there is a legitimate bug in pandas 2.x.\n\n### Expected Behavior\n\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(data={\'order_id\': [\'a1\', \'a1\', \'a2\'], \'size_filled\': [0, 2, 0], \'state\': [\'NEW\', \'FILLED\', \'NEW\']})\r\n>>> df.groupby(\'order_id\', observed=True, as_index=True).nth(0)\r\n          size_filled state\r\norder_id\r\na1                  0   NEW\r\na2                  0   NEW\n\n### Installed Versions\n\n<details>\r\n\r\n>>> pd.show_versions()\r\n/Users/john/miniconda3/envs/pandas2/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : e86ed377639948c64c429059127bcf5b359ab6be\r\npython              : 3.11.5.final.0\r\npython-bits         : 64\r\nOS                  : Darwin\r\nOS-release          : 23.0.0\r\nVersion             : Darwin Kernel Version 23.0.0: Fri Sep 15 14:43:05 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6020\r\nmachine             : arm64\r\nprocessor           : arm\r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : en_US.UTF-8\r\nLOCALE              : en_US.UTF-8\r\n\r\npandas              : 2.1.1\r\nnumpy               : 1.26.0\r\npytz                : 2023.3.post1\r\ndateutil            : 2.8.2\r\nsetuptools          : 68.0.0\r\npip                 : 23.2.1\r\nCython              : None\r\npytest              : 7.4.2\r\nhypothesis          : None\r\nsphinx              : None\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : None\r\nlxml.etree          : 4.9.3\r\nhtml5lib            : 1.1\r\npymysql             : None\r\npsycopg2            : None\r\njinja2              : 3.1.2\r\nIPython             : None\r\npandas_datareader   : None\r\nbs4                 : 4.12.2\r\nbottleneck          : 1.3.7\r\ndataframe-api-compat: None\r\nfastparquet         : None\r\nfsspec              : None\r\ngcsfs               : None\r\nmatplotlib          : 3.8.0\r\nnumba               : None\r\nnumexpr             : 2.8.6\r\nodfpy               : None\r\nopenpyxl            : 3.1.2\r\npandas_gbq          : None\r\npyarrow             : None\r\npyreadstat          : None\r\npyxlsb              : None\r\ns3fs                : None\r\nscipy               : 1.11.2\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : 0.9.0\r\nxarray               ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55334/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55334/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55333',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55333/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55333/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55333/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55333',
#   'id': 1920323446,
#   'node_id': 'I_kwDOAA0YD85ydc92',
#   'number': 55333,
#   'title': 'BUG/TST: can_use_libjoin cases with mixed-freq Periods',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-09-30T16:30:44Z',
#   'updated_at': '2023-09-30T19:13:39Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "In the Index code we have a fastpaths in for _union, _intersection and join, that look something like\r\n\r\n```\r\nif self._can_use_libjoin and [...]\r\n     try:\r\n        result = self._use_fastpath(...)\r\n     except TypeError:\r\n         # object dtype, non-comparable objects\r\n         result = self._non_fastpath(...)\r\n```\r\n\r\n`_union` also catches IncompatibleFrequency (which subclasses ValueError instead of TypeError, which itself might be something to somehow deprecate) which is what you get if you try to sort Period objects with mismatched freqs.\r\n\r\nI'm _guessing_ that the _intersection and join paths should also catch IncompatibleFrequency.  Either that or check that we have test cases that get there with mismatches Periods inside object dtype indexes.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55333/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55333/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55332',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55332/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55332/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55332/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55332',
#   'id': 1920211451,
#   'node_id': 'I_kwDOAA0YD85ydBn7',
#   'number': 55332,
#   'title': 'BUG: DataFrame Interchange Protocol errors on Boolean columns',
#   'user': {'login': 'jonmmease',
#    'id': 15064365,
#    'node_id': 'MDQ6VXNlcjE1MDY0MzY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15064365?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonmmease',
#    'html_url': 'https://github.com/jonmmease',
#    'followers_url': 'https://api.github.com/users/jonmmease/followers',
#    'following_url': 'https://api.github.com/users/jonmmease/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonmmease/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonmmease/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonmmease/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonmmease/orgs',
#    'repos_url': 'https://api.github.com/users/jonmmease/repos',
#    'events_url': 'https://api.github.com/users/jonmmease/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonmmease/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-30T10:45:42Z',
#   'updated_at': '2023-09-30T19:34:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pyarrow.interchange as pai\r\nimport pandas as pd\r\n\r\ndata = pd.DataFrame(\r\n    {\r\n        "b": pd.Series([True, False], dtype="boolean"),\r\n    }\r\n)\r\nprint(data.dtypes)\r\npai.from_dataframe(data)\n```\n\n\n### Issue Description\n\nWhen converting a pandas DataFrame using the DataFrame Interchange Protocol, boolean columns result in an exception:\r\n\r\n```\r\n---------------------------------------------------------------------------\r\nAttributeError                            Traceback (most recent call last)\r\nCell In [8], line 10\r\n      4 data = pd.DataFrame(\r\n      5     {\r\n      6         "b": pd.Series([True, False], dtype="boolean"),\r\n      7     }\r\n      8 )\r\n      9 print(data.dtypes)\r\n---> 10 pai.from_dataframe(data)\r\n\r\nFile ~/miniconda3/envs/altair-dev/lib/python3.10/site-packages/pyarrow/interchange/from_dataframe.py:111, in from_dataframe(df, allow_copy)\r\n    108 if not hasattr(df, "__dataframe__"):\r\n    109     raise ValueError("`df` does not support __dataframe__")\r\n--> 111 return _from_dataframe(df.__dataframe__(allow_copy=allow_copy),\r\n    112                        allow_copy=allow_copy)\r\n\r\nFile ~/miniconda3/envs/altair-dev/lib/python3.10/site-packages/pyarrow/interchange/from_dataframe.py:134, in _from_dataframe(df, allow_copy)\r\n    132 batches = []\r\n    133 for chunk in df.get_chunks():\r\n--> 134     batch = protocol_df_chunk_to_pyarrow(chunk, allow_copy)\r\n    135     batches.append(batch)\r\n    137 return pa.Table.from_batches(batches)\r\n\r\nFile ~/miniconda3/envs/altair-dev/lib/python3.10/site-packages/pyarrow/interchange/from_dataframe.py:168, in protocol_df_chunk_to_pyarrow(df, allow_copy)\r\n    166     raise ValueError(f"Column {name} is not unique")\r\n    167 col = df.get_column_by_name(name)\r\n--> 168 dtype = col.dtype[0]\r\n    169 if dtype in (\r\n    170     DtypeKind.INT,\r\n    171     DtypeKind.UINT,\r\n   (...)\r\n    174     DtypeKind.DATETIME,\r\n    175 ):\r\n    176     columns[name] = column_to_array(col, allow_copy)\r\n\r\nFile properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()\r\n\r\nFile ~/miniconda3/envs/altair-dev/lib/python3.10/site-packages/pandas/core/interchange/column.py:128, in PandasColumn.dtype(self)\r\n    126     raise NotImplementedError("Non-string object dtypes are not supported yet")\r\n    127 else:\r\n--> 128     return self._dtype_from_pandasdtype(dtype)\r\n\r\nFile ~/miniconda3/envs/altair-dev/lib/python3.10/site-packages/pandas/core/interchange/column.py:147, in PandasColumn._dtype_from_pandasdtype(self, dtype)\r\n    145     byteorder = dtype.base.byteorder  # type: ignore[union-attr]\r\n    146 else:\r\n--> 147     byteorder = dtype.byteorder\r\n    149 return kind, dtype.itemsize * 8, dtype_to_arrow_c_fmt(dtype), byteorder\r\n\r\nAttributeError: \'BooleanDtype\' object has no attribute \'byteorder\'\r\n```\n\n### Expected Behavior\n\nI expect the example above to successfully convert the pandas DataFrame to an Arrow table using the DataFrame Interchange Protocol.\r\n\r\nOriginally reported in the Vega-Altair project as https://github.com/altair-viz/altair/issues/3205\r\n\r\nIf it\'s not straightforward to support boolean columns, I would ask that an explicit `NotImplementedException` be raised (instead of an `AttributeError`). Vega-Altair uses this as an indication to fall back to an alternative implementation.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : e ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55332/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55332/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55331',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55331/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55331/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55331/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55331',
#   'id': 1920074530,
#   'node_id': 'PR_kwDOAA0YD85blF_L',
#   'number': 55331,
#   'title': 'BLD: Fix gitpod meson version',
#   'user': {'login': 'theuerc',
#    'id': 60138157,
#    'node_id': 'MDQ6VXNlcjYwMTM4MTU3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60138157?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/theuerc',
#    'html_url': 'https://github.com/theuerc',
#    'followers_url': 'https://api.github.com/users/theuerc/followers',
#    'following_url': 'https://api.github.com/users/theuerc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/theuerc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/theuerc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/theuerc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/theuerc/orgs',
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55308/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55308/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55306',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55306/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55306/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55306/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55306',
#   'id': 1915636748,
#   'node_id': 'PR_kwDOAA0YD85bWAQU',
#   'number': 55306,
#   'title': 'ENH: case_when function',
#   'user': {'login': 'samukweku',
#    'id': 25709809,
#    'node_id': 'MDQ6VXNlcjI1NzA5ODA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25709809?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/samukweku',
#    'html_url': 'https://github.com/samukweku',
#    'followers_url': 'https://api.github.com/users/samukweku/followers',
#    'following_url': 'https://api.github.com/users/samukweku/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/samukweku/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/samukweku/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/samukweku/subscriptions',
#    'organizations_url': 'https://api.github.com/users/samukweku/orgs',
#    'repos_url': 'https://api.github.com/users/samukweku/repos',
#    'events_url': 'https://api.github.com/users/samukweku/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/samukweku/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-27T13:49:27Z',
#   'updated_at': '2023-09-30T08:35:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55306',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55306',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55306.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55306.patch',
#    'merged_at': None},
#   'body': '- [x] closes #39154 \r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nContinues the work started by @ElHoussineT(#50343)\r\n\r\n- uses `pd.Series.mask` under the hood\r\n- function implementation, as well as a Series method',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55306/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55306/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55305',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55305/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55305/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55305/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55305',
#   'id': 1914754229,
#   'node_id': 'I_kwDOAA0YD85yINS1',
#   'number': 55305,
#   'title': "BUG: ValueError: Buffer dtype mismatch, expected 'intp_t' but got 'long long' on ARMv7 32 bit",
#   'user': {'login': 'scinteeb',
#    'id': 36276309,
#    'node_id': 'MDQ6VXNlcjM2Mjc2MzA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36276309?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scinteeb',
#    'html_url': 'https://github.com/scinteeb',
#    'followers_url': 'https://api.github.com/users/scinteeb/followers',
#    'following_url': 'https://api.github.com/users/scinteeb/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/scinteeb/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/scinteeb/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/scinteeb/subscriptions',
#    'organizations_url': 'https://api.github.com/users/scinteeb/orgs',
#    'repos_url': 'https://api.github.com/users/scinteeb/repos',
#    'events_url': 'https://api.github.com/users/scinteeb/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/scinteeb/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-27T05:58:07Z',
#   'updated_at': '2023-09-27T05:58:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\n# Create a list of data\r\ndata = [["Alice", 25], ["Bob", 30], ["Carol", 35]]\r\n\r\n# Create a Pandas DataFrame from the list of data\r\ndf = pd.DataFrame(data, columns=["Name", "Age"])\r\n\r\n# Print the DataFrame\r\nprint(df)\n```\n\n\n### Issue Description\n\nThe simplest test on a dataframe object is failing on an embedded 32bit device with ARMv7 CPU. No matter how the dataframe is created, from an array or read from a csv file using read_csv, access on the object fails the same:\r\n\r\n  File "pandas/_libs/internals.pyx", line 711, in pandas._libs.internals.BlockManager._rebuild_blknos_and_blklocs\r\nValueError: Buffer dtype mismatch, expected \'intp_t\' but got \'long long\'\r\n\r\nUnfortunately, on that platform I cannot compile a newer version of pandas, so I cannot verify if the issue is present in the latest version or main branch.\n\n### Expected Behavior\n\nThe expected output is:\r\n    Name  Age\r\n0  Alice   25\r\n1    Bob   30\r\n2  Carol   35\r\n\r\nbut running the script is giving:\r\n  File "/home/root/test.py", line 10, in <module>\r\n    print(df)\r\n  File "/usr/lib/python3.10/site-packages/pandas/core/frame.py", line 1011, in __repr__\r\n    return self.to_string(**repr_params)\r\n  File "/usr/lib/python3.10/site-packages/pandas/core/frame.py", line 1192, in to_string\r\n    return fmt.DataFrameRenderer(formatter).to_string(\r\n  File "/usr/lib/python3.10/site-packages/pandas/io/formats/format.py", line 1128, in to_string\r\n    string = string_formatter.to_string()\r\n  File "/usr/lib/python3.10/site-packages/pandas/io/formats/string.py", line 25, in to_string\r\n    text = self._get_string_representation()\r\n  File "/usr/lib/python3.10/site-packages/pandas/io/formats/string.py", line 40, in _get_string_representation\r\n    strcols = self._get_strcols()\r\n  File "/usr/lib/python3.10/site-packages/pandas/io/formats/string.py", line 31, in _get_strcols\r\n    strcols = self.fmt.get_strcols()\r\n  File "/usr/lib/python3.10/site-packages/pandas/io/formats/format.py", line 611, in get_strcols\r\n    strcols = self._get_strcols_without_index()\r\n  File "/usr/lib/python3.10/site-packages/pandas/io/formats/format.py", line 864, in _get_strcols_without_index\r\n    str_columns = self._get_formatted_column_labels(self.tr_frame)\r\n  File "/usr/lib/python3.10/site-packages/pandas/io/formats/format.py", line 943, in _get_formatted_column_labels\r\n    dtypes = self.frame.dtypes\r\n  File "/usr/lib/python3.10/site-packages/pandas/core/generic.py", line 5746, in dtypes\r\n    data = self._mgr.get_dtypes()\r\n  File "/usr/lib/python3.10/site-packages/pandas/core/internals/managers.py", line 228, in get_dtypes\r\n    return dtypes.take(self.blknos)\r\n  File "/usr/lib/python3.10/site-packages/pandas/core/internals/managers.py", line 168, in blknos\r\n    self._rebuild_blknos_and_blklocs()\r\n  File "pandas/_libs/internals.pyx", line 711, in pandas._libs.internals.BlockManager._rebuild_blknos_and_blklocs\r\nValueError: Buffer dtype mismatch, expected \'intp_t\' but got \'long long\'\r\n\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.10.4.final.0\r\npython-bits      : 32\r\nOS               : Linux\r\nOS-release       : 5.15.32-yoctoEMB+gddbcf3882cd3\r\nVersion          : #1 SMP PREEMPT Thu Apr 13 04:27:17 UTC 2023\r\nmachine          : armv7l\r\nprocessor        : armv7l\r\nbyteorder        : little\r\nLC_AL ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55305/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55305/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55304',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55304/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55304/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55304/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55304',
#   'id': 1914609861,
#   'node_id': 'PR_kwDOAA0YD85bSj5Z',
#   'number': 55304,
#   'title': 'Valid capitalization errors #32550',
#   'user': {'login': 'suresh33661',
#    'id': 132880363,
#    'node_id': 'U_kgDOB-uX6w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/132880363?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/suresh33661',
#    'html_url': 'https://github.com/suresh33661',
#    'followers_url': 'https://api.github.com/users/suresh33661/followers',
#    'following_url': 'https://api.github.com/users/suresh33661/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/suresh33661/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/suresh33661/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/suresh33661/subscriptions',
#    'organizations_url': 'https://api.github.com/users/suresh33661/orgs',
#    'repos_url': 'https://api.github.com/users/suresh33661/repos',
#    'events_url': 'https://api.github.com/users/suresh33661/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/suresh33661/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-27T03:10:33Z',
#   'updated_at': '2023-09-28T01:52:45Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55304',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55304',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55304.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55304.patch',
#    'merged_at': None},
#   'body': '- [x] Fix capitalization at [Fix capitalization among headings in documentation files #32550](https://github.com/pandas-dev/pandas/issues/32550)\r\n- [x] https://github.com/pandas-dev/pandas/blob/main/doc/source/development/contributing_docstring.rst\r\n- [x] https://github.com/pandas-dev/pandas/blob/main/doc/source/development/contributing_documentation.rst',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55304/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55304/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 18441788
# 8078968
# 61934744
# 61934744
# 96156234
# 61934744
# 8078968
# 18432229
# 8078968
# 15064365
# 60138157
# 6618166
# 91160475
# 47963215
# 45562402
# 29018159
# 48098178
# 47397283
# 1448202
# 89194651
# 45562402
# 12912975
# 2836374
# 45562402
# 45562402
# 33491632
# 5097759
# 25709809
# 36276309
# 132880363

# %%
pd.DataFrame(data1, columns=['url','repository_url','labels_url'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
df2 = pd.DataFrame(data1, columns=['url','repository_url','labels_url','user'])

# %%
df2
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'qianyun210603', 'id': 18441788, 'no...
# 1   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 2   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 3   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 4   {'login': 'paulreece', 'id': 96156234, 'node_i...
# 5   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 6   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 7   {'login': 'idealcrouch', 'id': 18432229, 'node...
# 8   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9   {'login': 'jonmmease', 'id': 15064365, 'node_i...
# 10  {'login': 'theuerc', 'id': 60138157, 'node_id'...
# 11  {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 12  {'login': 'natmokval', 'id': 91160475, 'node_i...
# 13  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 14  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 15  {'login': 'mzuzek', 'id': 29018159, 'node_id':...
# 16  {'login': 'PabloRuizCuevas', 'id': 48098178, '...
# 17  {'login': 'daleschyov', 'id': 47397283, 'node_...
# 18  {'login': 'DaveSprague', 'id': 1448202, 'node_...
# 19  {'login': 'PiotrekB416', 'id': 89194651, 'node...
# 20  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 21  {'login': 'OleFass', 'id': 12912975, 'node_id'...
# 22  {'login': 'timhoffm', 'id': 2836374, 'node_id'...
# 23  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 24  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 25  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 26  {'login': 'caneff', 'id': 5097759, 'node_id': ...
# 27  {'login': 'samukweku', 'id': 25709809, 'node_i...
# 28  {'login': 'scinteeb', 'id': 36276309, 'node_id...
# 29  {'login': 'suresh33661', 'id': 132880363, 'nod...
