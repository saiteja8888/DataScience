# %%
import pandas as pd

# %%
ls
# Out:
# 0_Resources/  1_Pandas.ipynb  cricket.csv  NBA1.csv  NBA2.csv  NBA.csv

# %%
pd.read_csv("sample.csv")
# Out:
#     name             emailid    address  pincode sirname
# 0   sudh   sskumar@gmail.com  bengalore   560085   kumar
# 1  krish     krish@gmail.com  bengalore   560085    naik
# 2    sai       sai@gmail.com  hyderabad   500084     sai

# %%
df = pd.read_csv("sample.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("sample.csv",header=None)
# Out:
#        0                   1          2        3        4
# 0   name             emailid    address  pincode  sirname
# 1   sudh   sskumar@gmail.com  bengalore   560085    kumar
# 2  krish     krish@gmail.com  bengalore   560085     naik
# 3    sai       sai@gmail.com  hyderabad   500084      sai

# %%
pd.read_csv("sample.csv",header=None, names=['col1','col2','col3','col4','col5'])
# Out:
#     col1                col2       col3     col4     col5
# 0   name             emailid    address  pincode  sirname
# 1   sudh   sskumar@gmail.com  bengalore   560085    kumar
# 2  krish     krish@gmail.com  bengalore   560085     naik
# 3    sai       sai@gmail.com  hyderabad   500084      sai

# %%
pd.read_csv("sample.csv",header=None, names=['col1','col2','col3','col4','col5','col6'])
# Out:
#     col1                col2       col3     col4     col5  col6
# 0   name             emailid    address  pincode  sirname   NaN
# 1   sudh   sskumar@gmail.com  bengalore   560085    kumar   NaN
# 2  krish     krish@gmail.com  bengalore   560085     naik   NaN
# 3    sai       sai@gmail.com  hyderabad   500084      sai   NaN

# %%
pd.read_csv("sample.csv",header=None, names=['col1','col2','col3','col4'])
# Out:
#                      col1       col2     col3     col4
# name              emailid    address  pincode  sirname
# sudh    sskumar@gmail.com  bengalore   560085    kumar
# krish     krish@gmail.com  bengalore   560085     naik
# sai         sai@gmail.com  hyderabad   500084      sai

# %%
pd.read_csv("sample.csv",header=None, names=['col1','col2','col3'])
# Out:
#                                col1     col2     col3
# name  emailid               address  pincode  sirname
# sudh   sskumar@gmail.com  bengalore   560085    kumar
# krish krish@gmail.com     bengalore   560085     naik
# sai   sai@gmail.com       hyderabad   500084      sai

# %%
pd.read_csv("sample.csv", names=['col1','col2','col3','col4','col5'],sep=',')
# Out:
#     col1                col2       col3     col4     col5
# 0   name             emailid    address  pincode  sirname
# 1   sudh   sskumar@gmail.com  bengalore   560085    kumar
# 2  krish     krish@gmail.com  bengalore   560085     naik
# 3    sai       sai@gmail.com  hyderabad   500084      sai

# %%
df
# Out:
#     name             emailid    address  pincode sirname
# 0   sudh   sskumar@gmail.com  bengalore   560085   kumar
# 1  krish     krish@gmail.com  bengalore   560085    naik
# 2    sai       sai@gmail.com  hyderabad   500084     sai

# %%
pd.read_csv("sample.csv", names=['col1','col2','col3','col4','col5'],sep=',',skiprows=[1,2])
# Out:
#    col1           col2       col3     col4     col5
# 0  name        emailid    address  pincode  sirname
# 1   sai  sai@gmail.com  hyderabad   500084      sai

# %%
df.dtypes
# Out:
# name       object
# emailid    object
# address    object
# pincode     int64
# sirname    object
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'emailid', 'address', 'pincode', 'sirname'], dtype='object')

# %%
df.head()
# Out:
#     name             emailid    address  pincode sirname
# 0   sudh   sskumar@gmail.com  bengalore   560085   kumar
# 1  krish     krish@gmail.com  bengalore   560085    naik
# 2    sai       sai@gmail.com  hyderabad   500084     sai

# %%
df.tail()
# Out:
#     name             emailid    address  pincode sirname
# 0   sudh   sskumar@gmail.com  bengalore   560085   kumar
# 1  krish     krish@gmail.com  bengalore   560085    naik
# 2    sai       sai@gmail.com  hyderabad   500084     sai

# %%
df.tail(1)
# Out:
#   name        emailid    address  pincode sirname
# 2  sai  sai@gmail.com  hyderabad   500084     sai

# %%
df.tail(2)
# Out:
#     name          emailid    address  pincode sirname
# 1  krish  krish@gmail.com  bengalore   560085    naik
# 2    sai    sai@gmail.com  hyderabad   500084     sai

# %%
df = pd.read_csv("sample.csv", names=['col1','col2','col3','col4','col5'],sep=',',skiprows=[1,2],)

# %%
df[['col1','col3']]
# Out:
#    col1       col3
# 0  name    address
# 1   sai  hyderabad

# %%
a = df['col1']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a = df[['col1']]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('LUSIDExcel-BusinessAgility-MakingSimpleChangesQuicklyEasily.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
temp = pd.ExcelFile('LUSIDExcel-BusinessAgility-MakingSimpleChangesQuicklyEasily.xlsx')

# %%
temp.sheet_names
# Out:
# ['Create Portfolio',
#  'Introduction',
#  'Create your instrument universe',
#  'Add your take on balances',
#  'Create your test environment',
#  'Make live trades in production',
#  'Add some test transactions',
#  'Inputs']

# %%
pd.read_excel('LUSIDExcel-BusinessAgility-MakingSimpleChangesQuicklyEasily.xlsx',sheet_name='Create your instrument universe')
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN         NaN           NaN        NaN
# 1          NaN         NaN        NaN         NaN           NaN        NaN
# 2          NaN         NaN        NaN         NaN           NaN        NaN
# 3          NaN         NaN        NaN         NaN           NaN        NaN
# 4          NaN         NaN        NaN         NaN           NaN        NaN
# ..         ...         ...        ...         ...           ...        ...
# 66         NaN         NaN        NaN         NaN  BBG0000D14P3     Active
# 67         NaN         NaN        NaN         NaN  BBG00FN3B5K8     Active
# 68         NaN         NaN        NaN         NaN  BBG000DQQNJ8     Active
# 69         NaN         NaN        NaN         NaN  BBG000BF6B57     Active
# 70         NaN         NaN        NaN         NaN  BBG000BRVH05     Active
#
# ...

# %%
pd.read_csv('https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...
