# %%
import pandas as pd

# %%
df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
len(df)
# Out:
# 1

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
df[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
type(df)
# Out:
# list

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1.to_csv('NBA.csv')

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA1.csv',index=False)

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
#    1222     encoding=encoding,
#    1223     decimal=decimal,
#    1224     converters=converters,
#    1225     na_values=na_values,
#    1226     keep_default_na=keep_default_na,
#    1227     displayed_only=displayed_only,
#    1228     extract_links=extract_links,
#    1229     dtype_backend=dtype_backend,
#    1230 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/html.py:981, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     978 p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     980 try:
# --> 981     tables = p.parse_tables()
#     982 except ValueError as caught:
#     983     # if `io` is an io-like object, check if it's seekable
#     984     # and try to rewind it before trying the next parser
#     985     if hasattr(io, "seekable") and io.seekable():
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/html.py:257, in _HtmlFrameParser.parse_tables(self)
#     249 def parse_tables(self):
#     250     """
#     251     Parse and return all tables from the DOM.
#     252
#    (...)
#     255     list of parsed (header, body, footer) tuples from tables.
#     256     """
# --> 257     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     258     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/html.py:797, in _LxmlFrameParser._build_doc(self)
#     795 try:
#     796     if is_url(self.io):
# --> 797         with urlopen(self.io) as f:
#     798             r = parse(f, parser=parser)
#     799     else:
#     800         # try to parse the input in the simplest way
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/common.py:270, in urlopen(*args, **kwargs)
#     264 """
#     265 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     266 the stdlib.
#     267 """
#     268 import urllib.request
# --> 270 return urllib.request.urlopen(*args, **kwargs)
#
# File /usr/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File /usr/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File /usr/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File /usr/lib/python3.8/urllib/request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.8/urllib/request.py:1358, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1356     except OSError as err: # timeout error
#    1357         raise URLError(err)
# -> 1358     r = h.getresponse()
#    1359 except:
#    1360     h.close()
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /usr/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Sudhanshu kumar',
#  'email id ': 'sskumar@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/56221  2014356123
# 1     https://github.com/pandas-dev/pandas/pull/56220  2014261711
# 2     https://github.com/pandas-dev/pandas/pull/56219  2013776658
# 3   https://github.com/pandas-dev/pandas/issues/56218  2013667137
# 4     https://github.com/pandas-dev/pandas/pull/56217  2013367045
# 5     https://github.com/pandas-dev/pandas/pull/56215  2013338895
# 6     https://github.com/pandas-dev/pandas/pull/56214  2013308111
# 7   https://github.com/pandas-dev/pandas/issues/56213  2013226081
# 8     https://github.com/pandas-dev/pandas/pull/56212  2013180700
# 9     https://github.com/pandas-dev/pandas/pull/56211  2013152202
# 10    https://github.com/pandas-dev/pandas/pull/56210  2013018133
# 11    https://github.com/pandas-dev/pandas/pull/56209  2013017507
# 12    https://github.com/pandas-dev/pandas/pull/56207  2012791558
# 13  https://github.com/pandas-dev/pandas/issues/56204  2012043795
# 14  https://github.com/pandas-dev/pandas/issues/56203  2011950897
# 15    https://github.com/pandas-dev/pandas/pull/56201  2011416854
# 16    https://github.com/pandas-dev/pandas/pull/56200  2011394639
# 17    https://github.com/pandas-dev/pandas/pull/56197  2011264070
# 18    https://github.com/pandas-dev/pandas/pull/56192  2011215972
# 19    https://github.com/pandas-dev/pandas/pull/56191  2011207750
# 20    https://github.com/pandas-dev/pandas/pull/56190  2011194283
# 21    https://github.com/pandas-dev/pandas/pull/56188  2011187087
# 22    https://github.com/pandas-dev/pandas/pull/56187  2011186941
# 23    https://github.com/pandas-dev/pandas/pull/56186  2011177422
# 24    https://github.com/pandas-dev/pandas/pull/56184  2011140992
# 25    https://github.com/pandas-dev/pandas/pull/56183  2011139111
# 26    https://github.com/pandas-dev/pandas/pull/56179  2011126080
# 27  https://github.com/pandas-dev/pandas/issues/56177  2011121307
# 28    https://github.com/pandas-dev/pandas/pull/56175  2010847581
# 29    https://github.com/pandas-dev/pandas/pull/56174  2010835640
#
#                 node_id  number  \
# 0    I_kwDOAA0YD854EKKb   56221
# 1   PR_kwDOAA0YD85gi3TA   56220
# 2   PR_kwDOAA0YD85ghOX6   56219
# 3    I_kwDOAA0YD854Bh9B   56218
# 4   PR_kwDOAA0YD85gf07p   56217
# 5   PR_kwDOAA0YD85gfuw7   56215
# 6   PR_kwDOAA0YD85gfn7d   56214
# 7    I_kwDOAA0YD853_2Rh   56213
# 8   PR_kwDOAA0YD85gfLaq   56212
# 9   PR_kwDOAA0YD85gfFAd   56211
# 10  PR_kwDOAA0YD85geneP   56210
# 11  PR_kwDOAA0YD85genVO   56209
# 12  PR_kwDOAA0YD85gd1wE   56207
# 13   I_kwDOAA0YD8537VoT   56204
# 14   I_kwDOAA0YD8536-8x   56203
# 15  PR_kwDOAA0YD85gZK1j   56201
# 16  PR_kwDOAA0YD85gZGFX   56200
# 17  PR_kwDOAA0YD85gYqxE   56197
# 18  PR_kwDOAA0YD85gYg-h   56192
# 19  PR_kwDOAA0YD85gYfVk   56191
# 20  PR_kwDOAA0YD85gYcqB   56190
# 21  PR_kwDOAA0YD85gYbQ5   56188
# 22  PR_kwDOAA0YD85gYbPG   56187
# 23  PR_kwDOAA0YD85gYZYf   56186
# 24  PR_kwDOAA0YD85gYSHI   56184
# 25  PR_kwDOAA0YD85gYRzC   56183
# 26  PR_kwDOAA0YD85gYPPK   56179
# 27   I_kwDOAA0YD85330ab   56177
# 28  PR_kwDOAA0YD85gXYlX   56175
# 29  PR_kwDOAA0YD85gXWSA   56174
#
#                                                 title  ... closed_at  \
# 0   BUG: `pd.nlargest` with `keep='all'` does not ...  ...       NaT
# 1   Switch arrow type for string array to large st...  ...       NaT
# 2                      DOC: DataFrame.update doctests  ...       NaT
# 3   BUG: `DataFrame.astype` does not suppress exce...  ...       NaT
# 4                             TST: specify dt64 units  ...       NaT
# 5   CoW: Avoid warning for ArrowDtypes when settin...  ...       NaT
# 6   CoW: Add warning for slicing a Series with a M...  ...       NaT
# 7   BUG: inconsistency in freq of DatetimeIndex wh...  ...       NaT
# 8   CoW: Avoid warning in apply for mixed dtype frame  ...       NaT
# 9    CoW: Avoid warning if temporary object is a copy  ...       NaT
# 10                      TST/CLN: Remove makeDataFrame  ...       NaT
# 11  Update indexing unpacking logic for single blo...  ...       NaT
# 12                 WEB: Better management of releases  ...       NaT
# 13  BUG: Creating a string column on a mask result...  ...       NaT
# 14  BUG: expanding dataframe row-wise with single-...  ...       NaT
# 15  DOC: Add clarifications to docs for setting up...  ...       NaT
# 16      TST/CLN: Remove makeUInt/Timedelta/RangeIndex  ...       NaT
# 17  Adjust tests in json folder for new string option  ...       NaT
# 18  Adjust tests in parsers folder for new string ...  ...       NaT
# 19  Adjust tests in extension folder for new strin...  ...       NaT
# 20  Adjust tests for apply folder for new string o...  ...       NaT
# 21  Adjust tests in array folder for new string op...  ...       NaT
# 22      BUG: value_counts not preserving object dtype  ...       NaT
# 23               TST/CLN: Remove makeCategoricalIndex  ...       NaT
# 24  Adjust tests in root directory for new string ...  ...       NaT
# 25  BUG: mode not preserving object dtype for stri...  ...       NaT
# 26  BUG: to_numeric casting to ea for new string d...  ...       NaT
# 27                                 RLS: Release 2.1.4  ...       NaT
# 28  ENH: Allow dictionaries to be passed to pandas...  ...       NaT
# 29                                CI: Add 3.12 builds  ...       NaT
#
#    author_association active_lock_reason  \
# 0                NONE                NaN
# 1              MEMBER                NaN
# 2         CONTRIBUTOR                NaN
# 3         CONTRIBUTOR                NaN
# 4              MEMBER                NaN
# 5              MEMBER                NaN
# 6              MEMBER                NaN
# 7         CONTRIBUTOR                NaN
# 8              MEMBER                NaN
# 9              MEMBER                NaN
# 10             MEMBER                NaN
# 11             MEMBER                NaN
# 12               NONE                NaN
# 13               NONE                NaN
# 14             MEMBER                NaN
# 15        CONTRIBUTOR                NaN
# 16             MEMBER                NaN
# 17             MEMBER                NaN
# 18             MEMBER                NaN
# 19             MEMBER                NaN
# 20             MEMBER                NaN
# 21             MEMBER                NaN
# 22             MEMBER                NaN
# 23             MEMBER                NaN
# 24             MEMBER                NaN
# 25             MEMBER                NaN
# 26             MEMBER                NaN
# 27             MEMBER                NaN
# 28        CONTRIBUTOR                NaN
# 29             MEMBER                NaN
#
#                                                  body  \
# 0   ### Pandas version checks\n\n- [X] I have chec...
# 1   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 2   \r\n\r\nI felt this original documentation was...
# 3   ### Pandas version checks\n\n- [X] I have chec...
# 4                Aimed at trimming the diff in #55901
# 5   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 6   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 7   ### Pandas version checks\r\n\r\n- [X] I have ...
# 8   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 9   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 10                                               None
# 11  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 12  Added releases sorting by version number and s...
# 13  ### Pandas version checks\n\n- [X] I have chec...
# 14  ### Pandas version checks\n\n- [X] I have chec...
# 15  Hi all - having just been through the setup pr...
# 16                                               None
# 17                                     sits on #56195
# 18  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 19  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 20                                     sits on #56189
# 21                              sits on top of #56187
# 22  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 23                                               None
# 24                                     sits on #56183
# 25  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 26  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 27  Release Date: TBD (tentatively scheduled for D...
# 28  - [X] closes #51748 \r\n- [X] [Tests added and...
# 29  Some CoW warnings broke for 3.11, so we should...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   0.0
# 2                       NaN           NaN   0.0
# 3                       NaN           NaN   NaN
# 4                       NaN           NaN   0.0
# 5                       NaN           NaN   0.0
# 6                       NaN           NaN   0.0
# 7                       NaN           NaN   NaN
# 8                       NaN           NaN   0.0
# 9                       NaN           NaN   0.0
# 10                      NaN           NaN   0.0
# 11                      NaN           NaN   0.0
# 12                      NaN           NaN   0.0
# 13                      NaN           NaN   NaN
# 14                      NaN           NaN   NaN
# 15                      NaN           NaN   0.0
# 16                      NaN           NaN   0.0
# 17                      NaN           NaN   0.0
# 18                      NaN           NaN   0.0
# 19                      NaN           NaN   0.0
# 20                      NaN           NaN   0.0
# 21                      NaN           NaN   0.0
# 22                      NaN           NaN   0.0
# 23                      NaN           NaN   0.0
# 24                      NaN           NaN   0.0
# 25                      NaN           NaN   0.0
# 26                      NaN           NaN   0.0
# 27                      NaN           NaN   NaN
# 28                      NaN           NaN   0.0
# 29                      NaN           NaN   0.0
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                 NaN
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
# [30 rows x 30 columns]

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/56221',
#   'id': 2014356123,
#   'node_id': 'I_kwDOAA0YD854EKKb',
#   'number': 56221,
#   'title': "BUG: `pd.nlargest` with `keep='all'` does not return the correct result",
#   'user': {'login': 'psads-git',
#    'id': 75945439,
#    'node_id': 'MDQ6VXNlcjc1OTQ1NDM5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75945439?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/psads-git',
#    'html_url': 'https://github.com/psads-git',
#    'followers_url': 'https://api.github.com/users/psads-git/followers',
#    'following_url': 'https://api.github.com/users/psads-git/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/psads-git/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/psads-git/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/psads-git/subscriptions',
#    'organizations_url': 'https://api.github.com/users/psads-git/orgs',
#    'repos_url': 'https://api.github.com/users/psads-git/repos',
#    'events_url': 'https://api.github.com/users/psads-git/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/psads-git/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-28T12:43:12Z',
#   'updated_at': '2023-11-28T12:46:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\ntechnologies =  "A B C D E F G H I J".split()\r\nduration     = [88,70,50,87,77,88,77,88,1,87]\r\ncolumns      = [\'technologies\',\'duration\']\r\ndf = pd.DataFrame(list(zip(technologies,duration)), columns=columns)\r\ndf.nlargest(3, \'duration\', keep=\'all\')\n```\n\n\n### Issue Description\n\nAccording to the example that uses `keep=\'all\'`, the 3 top values and their duplicates should show up in the result, but only the value `88` is returned.\n\n### Expected Behavior\n\n```\r\n  technologies  duration\r\n0            A        88\r\n5            F        88\r\n7            H        88\r\n3            D        87\r\n9            J        87\r\n4            E        77\r\n6            G        77\r\n\r\n```\n\n### Installed Versions\n\n/home/x/myenv/lib64/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : 2a953cf80b77e4348bf50ed724f8abc0d814d9dd\r\npython              : 3.11.6.final.0\r\npython-bits         : 64\r\nOS                  : Linux\r\nOS-release          : 6.5.12-300.fc39.x86_64\r\nVersion             : #1 SMP PREEMPT_DYNAMIC Mon Nov 20 22:44:24 UTC 2023\r\nmachine             : x86_64\r\nprocessor           : \r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : en_US.utf8\r\nLOCALE              : en_US.UTF-8\r\n\r\npandas              : 2.1.3\r\nnumpy               : 1.26.2\r\npytz                : 2023.3.post1\r\ndateutil            : 2.8.2\r\nsetuptools          : 69.0.2\r\npip                 : 23.3.1\r\nCython              : 3.0.6\r\npytest              : None\r\nhypothesis          : None\r\nsphinx              : None\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : None\r\nlxml.etree          : 4.9.3\r\nhtml5lib            : 1.1\r\npymysql             : None\r\npsycopg2            : None\r\njinja2              : 3.1.2\r\nIPython             : 8.18.1\r\npandas_datareader   : None\r\nbs4                 : 4.12.2\r\nbottleneck          : None\r\ndataframe-api-compat: None\r\nfastparquet         : None\r\nfsspec              : 2023.10.0\r\ngcsfs               : None\r\nmatplotlib          : 3.8.2\r\nnumba               : 0.58.1\r\nnumexpr             : None\r\nodfpy               : None\r\nopenpyxl            : 3.1.2\r\npandas_gbq          : None\r\npyarrow             : None\r\npyreadstat          : None\r\npyxlsb              : None\r\ns3fs                : None\r\nscipy               : 1.11.4\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : None\r\nxarray              : None\r\nxlrd                : None\r\nzstandard           : None\r\ntzdata              : 2023.3\r\nqtpy                : None\r\npyqt5               : None\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56220',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56220/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56220/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56220/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56220',
#   'id': 2014261711,
#   'node_id': 'PR_kwDOAA0YD85gi3TA',
#   'number': 56220,
#   'title': 'Switch arrow type for string array to large string',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-28T11:48:41Z',
#   'updated_at': '2023-11-28T11:48:56Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56220',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56220',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56220.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56220.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\nlarge string is a more sensible default (take concatenates the chunks in pyarrow which can cause overflows pretty quickly), large string should avoid this\r\n\r\none todo for a follow up:\r\n\r\n- ensure interoperability with ``"string[pyarrow]"``\r\n\r\nLet\'s see if CI likes this',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56220/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56220/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56219',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56219/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56219/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56219/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56219',
#   'id': 2013776658,
#   'node_id': 'PR_kwDOAA0YD85ghOX6',
#   'number': 56219,
#   'title': 'DOC: DataFrame.update doctests',
#   'user': {'login': 'smij720',
#    'id': 122238526,
#    'node_id': 'U_kgDOB0k2Pg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/122238526?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smij720',
#    'html_url': 'https://github.com/smij720',
#    'followers_url': 'https://api.github.com/users/smij720/followers',
#    'following_url': 'https://api.github.com/users/smij720/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/smij720/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/smij720/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/smij720/subscriptions',
#    'organizations_url': 'https://api.github.com/users/smij720/orgs',
#    'repos_url': 'https://api.github.com/users/smij720/repos',
#    'events_url': 'https://api.github.com/users/smij720/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/smij720/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-28T06:53:02Z',
#   'updated_at': '2023-11-28T06:53:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56219',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56219',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56219.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56219.patch',
#    'merged_at': None},
#   'body': '\r\n\r\nI felt this original documentation was doing too much in this code block - the description doesn\'t match the second code example.\r\n\r\n<kbd><img width="762" alt="image" src="https://github.com/pandas-dev/pandas/assets/122238526/cd897229-5366-40d9-8034-5521b7ecd0e7"></kbd>\r\n\r\n\r\nSo I broke it out into these two separate examples:\r\n\r\n<kbd><img width="974" alt="image" src="https://github.com/pandas-dev/pandas/assets/122238526/36585ddc-d14b-485e-917e-e53f5609c4c3"></kbd>\r\n\r\n---\r\n\r\nI added this new example, which I would have found useful:\r\n\r\n<kbd><img width="935" alt="image" src="https://github.com/pandas-dev/pandas/assets/122238526/b82fffd1-c095-4784-a2ec-b764b9093a29"></kbd>\r\n\r\n\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56219/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56219/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56218',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56218/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56218/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56218/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/56218',
#   'id': 2013667137,
#   'node_id': 'I_kwDOAA0YD854Bh9B',
#   'number': 56218,
#   'title': 'BUG: `DataFrame.astype` does not suppress exceptions when dtype is ExtensionDtype and `errors="ignore"`',
#   'user': {'login': 'yuanx749',
#    'id': 47032563,
#    'node_id': 'MDQ6VXNlcjQ3MDMyNTYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47032563?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yuanx749',
#    'html_url': 'https://github.com/yuanx749',
#    'followers_url': 'https://api.github.com/users/yuanx749/followers',
#    'following_url': 'https://api.github.com/users/yuanx749/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yuanx749/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yuanx749/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yuanx749/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yuanx749/orgs',
#    'repos_url': 'https://api.github.com/users/yuanx749/repos',
#    'events_url': 'https://api.github.com/users/yuanx749/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yuanx749/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'yuanx749',
#    'id': 47032563,
#    'node_id': 'MDQ6VXNlcjQ3MDMyNTYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47032563?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yuanx749',
#    'html_url': 'https://github.com/yuanx749',
#    'followers_url': 'https://api.github.com/users/yuanx749/followers',
#    'following_url': 'https://api.github.com/users/yuanx749/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yuanx749/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yuanx749/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yuanx749/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yuanx749/orgs',
#    'repos_url': 'https://api.github.com/users/yuanx749/repos',
#    'events_url': 'https://api.github.com/users/yuanx749/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yuanx749/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'yuanx749',
#     'id': 47032563,
#     'node_id': 'MDQ6VXNlcjQ3MDMyNTYz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47032563?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/yuanx749',
#     'html_url': 'https://github.com/yuanx749',
#     'followers_url': 'https://api.github.com/users/yuanx749/followers',
#     'following_url': 'https://api.github.com/users/yuanx749/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/yuanx749/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/yuanx749/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/yuanx749/subscriptions',
#     'organizations_url': 'https://api.github.com/users/yuanx749/orgs',
#     'repos_url': 'https://api.github.com/users/yuanx749/repos',
#     'events_url': 'https://api.github.com/users/yuanx749/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/yuanx749/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-11-28T05:20:35Z',
#   'updated_at': '2023-11-28T06:23:19Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\nser = pd.Series(["a", "b", "c"])\r\nprint(ser.astype("Float64", errors="ignore"))  # not raise\r\n\r\ndf = pd.DataFrame(["a", "b", "c"])\r\nprint(df.astype("float64", errors="ignore"))  # not raise\r\n\r\nprint(df.astype("Float64", errors="ignore"))  # this raises\n```\n\n\n### Issue Description\n\nWhen a dataframe contains columns that can not be converted to an ExtensionDtype (such as Float64, Int64), `DataFrame.astype` raises an exception, though `errors="ignore"`. However, casting to a normal dtype or casting the column as a seris do not raise, as expected.\n\n### Expected Behavior\n\nI would expect no exception is raised when `errors="ignore"`.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : 4c520e35f95429ceaf91ea67cd2ced5aabba9619\r\npython                : 3.10.13.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 5.10.16.3-microsoft-standard-WSL2\r\nVersion               : #1 SMP Fri Apr 2 22:23:49 UTC 2021\r\nmachine               : x86_64\r\nprocessor             : x86_64\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : C.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas                : 2.2.0dev0+743.g4c520e35f9\r\nnumpy                 : 1.26.2\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 68.2.2\r\npip                   : 23.3.1\r\nCython                : 3.0.5\r\npytest                : 7.4.3\r\nhypothesis            : 6.91.0\r\nsphinx                : None\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : None\r\nIPython               : 8.18.1\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : None\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : None\r\ngcsfs                 : None\r\nmatplotlib            : None\r\nnumba                 : 0.58.1\r\nnumexpr               : 2.8.7\r\nodfpy                 : None\r\nopenpyxl              : None\r\npandas_gbq            : None\r\npyarrow               : None\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : None\r\nsqlalchemy            : None\r\ntables                : None\r\ntabulate              : None\r\nxarray                : None\r\nxlrd                  : None\r\nzstandard             : None\r\ntzdata                : 2023.3\r\nqtpy                  : None\r\npyqt5                 : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56218/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56218/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56217',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56217/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56217/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56217/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56217',
#   'id': 2013367045,
#   'node_id': 'PR_kwDOAA0YD85gf07p',
#   'number': 56217,
#   'title': 'TST: specify dt64 units',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-28T00:28:35Z',
#   'updated_at': '2023-11-28T00:28:35Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56217',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56217',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56217.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56217.patch',
#    'merged_at': None},
#   'body': 'Aimed at trimming the diff in #55901',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56217/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56217/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56215',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56215/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56215/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56215/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56215',
#   'id': 2013338895,
#   'node_id': 'PR_kwDOAA0YD85gfuw7',
#   'number': 56215,
#   'title': 'CoW: Avoid warning for ArrowDtypes when setting inplace',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-28T00:00:02Z',
#   'updated_at': '2023-11-28T00:00:29Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56215',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56215',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56215.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56215.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nWe shouldn't warn if we know that we are not actually inplace",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56215/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56215/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56214',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56214/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56214/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56214/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56214',
#   'id': 2013308111,
#   'node_id': 'PR_kwDOAA0YD85gfn7d',
#   'number': 56214,
#   'title': 'CoW: Add warning for slicing a Series with a MultiIndex',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-27T23:29:08Z',
#   'updated_at': '2023-11-28T00:00:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56214',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56214',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56214.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56214.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56214/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56214/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56213',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56213/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56213/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56213/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/56213',
#   'id': 2013226081,
#   'node_id': 'I_kwDOAA0YD853_2Rh',
#   'number': 56213,
#   'title': 'BUG: inconsistency in freq of DatetimeIndex when converting PeriodIndex.to_timestamp',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-27T22:22:13Z',
#   'updated_at': '2023-11-27T22:32:35Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nper = pd.PeriodIndex(['2012-01', '2012-04', '2012-07'], dtype='period[Q]') \r\nper.to_timestamp(how='start')\r\n\r\nper = pd.PeriodIndex(['2012-01', '2012-04'], dtype='period[Q]') \r\nper.to_timestamp(how='start')\r\n\r\nper = pd.PeriodIndex(['2012-01', '2012-02', '2012-03'], dtype='period[M]') \r\nper.to_timestamp(how='start')\r\n\r\nper = pd.PeriodIndex(['2012-01', '2012-02'], dtype='period[M]') \r\nper.to_timestamp(how='start')\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nthis outputs\r\n\r\n>>> per = pd.PeriodIndex(['2012-01', '2012-04', '2012-07'], dtype='period[Q]') \r\n>>> per.to_timestamp(how='start')\r\nDatetimeIndex(['2012-01-01', '2012-04-01', '2012-07-01'], dtype='datetime64[ns]', freq='QS-OCT')\r\n\r\n>>> per = pd.PeriodIndex(['2012-01', '2012-04'], dtype='period[Q]') \r\n>>> per.to_timestamp(how='start')\r\nDatetimeIndex(['2012-01-01', '2012-04-01'], dtype='datetime64[ns]', freq=None)\r\n\r\n>>> per = pd.PeriodIndex(['2012-01', '2012-02', '2012-03'], dtype='period[M]') \r\n>>> per.to_timestamp(how='start')\r\nDatetimeIndex(['2012-01-01', '2012-02-01', '2012-03-01'], dtype='datetime64[ns]', freq='MS')\r\n\r\n>>> per = pd.PeriodIndex(['2012-01', '2012-02'], dtype='period[M]') \r\n>>> per.to_timestamp(how='start')\r\nDatetimeIndex(['2012-01-01', '2012-02-01'], dtype='datetime64[ns]', freq=None)\r\n\r\n### Expected Behavior\r\n\r\nduring conversion `PeriodIndex.to_timestamp` freq in DatetimeIndex unexpectedly depends on len of data. Shouldn't freqs in all examples above be equal ` 'QS-OCT'` and `'MS'`, but not `None`? \r\n\r\n>>> per = pd.PeriodIndex(['2012-01', '2012-04'], dtype='period[Q]') \r\n>>> per.to_timestamp(how='start')\r\nDatetimeIndex(['2012-01-01', '2012-04-01'], dtype='datetime64[ns]', freq='QS-OCT')\r\n\r\n>>> per = pd.PeriodIndex(['2012-01', '2012-02'], dtype='period[M]') \r\n>>> per.to_timestamp(how='start')\r\nDatetimeIndex(['2012-01-01', '2012-02-01'], dtype='datetime64[ns]', freq='MS')\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : b7a220731e901777f9d0a8da05c770764477c336\r\npython                : 3.10.13.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 4.19.0-22-amd64\r\nVersion               : #1 SMP Debian 4.19.260-1 (2022-09-29)\r\nmachine               : x86_64\r\nprocessor             : \r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_GB.UTF-8\r\nLOCALE                : en_GB.UTF-8\r\n\r\npandas                : 2.1.0.dev0+1330.gb7a220731e.dirty\r\nnumpy                 : 1.26.0\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 68.1.2\r\npip                   : 23.3.1\r\nCython                : 3.0.5\r\npytest                : 7.4.3\r\nhypothesis            : 6.89.0\r\nsphinx                : 7.2.6\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : 3.1.9\r\nlxml.etree            : 4.9.3\r\nhtml5lib              : 1.1\r\npymysql               : 1.4.6\r\npsycopg2              : 2.9.7\r\njinja2                : 3.1.2\r\nIPython               : 8.17.2\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.2\r\nbottleneck            : 1.3.7\r\ndataframe-api-compat  : None\r\nfastparquet           : 2023.10.1\r\nfsspec                : 2023.10.0\r\ngcsfs           ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56213/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56213/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56212',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56212/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56212/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56212/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56212',
#   'id': 2013180700,
#   'node_id': 'PR_kwDOAA0YD85gfLaq',
#   'number': 56212,
#   'title': 'CoW: Avoid warning in apply for mixed dtype frame',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-27T21:58:44Z',
#   'updated_at': '2023-11-27T23:20:20Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56212',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56212',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56212.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56212.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nYikes this is ugly',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56212/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56212/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56211',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56211/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56211/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56211/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56211',
#   'id': 2013152202,
#   'node_id': 'PR_kwDOAA0YD85gfFAd',
#   'number': 56211,
#   'title': 'CoW: Avoid warning if temporary object is a copy',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-27T21:40:28Z',
#   'updated_at': '2023-11-27T22:44:56Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56211',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56211',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56211.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56211.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\nThat's the stricter check we talked about today. The cases we exclude here are no-ops without CoW as well, so no need to warn",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56211/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56211/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56210',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56210/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56210/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56210/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56210',
#   'id': 2013018133,
#   'node_id': 'PR_kwDOAA0YD85geneP',
#   'number': 56210,
#   'title': 'TST/CLN: Remove makeDataFrame',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
# ...
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56183/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56179',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56179/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56179/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56179/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56179',
#   'id': 2011126080,
#   'node_id': 'PR_kwDOAA0YD85gYPPK',
#   'number': 56179,
#   'title': 'BUG: to_numeric casting to ea for new string dtype',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/113',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/113',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/113/labels',
#    'id': 10178781,
#    'node_id': 'MI_kwDOAA0YD84Am1Dd',
#    'number': 113,
#    'title': '2.1.4',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'jorisvandenbossche',
#     'id': 1020496,
#     'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jorisvandenbossche',
#     'html_url': 'https://github.com/jorisvandenbossche',
#     'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#     'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#     'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#     'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 28,
#    'closed_issues': 25,
#    'state': 'open',
#    'created_at': '2023-11-13T10:53:23Z',
#    'updated_at': '2023-11-27T14:25:58Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-11-26T17:24:35Z',
#   'updated_at': '2023-11-27T17:46:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56179',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56179',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56179.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56179.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56179/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56179/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56177',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56177/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56177/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56177/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/56177',
#   'id': 2011121307,
#   'node_id': 'I_kwDOAA0YD85330ab',
#   'number': 56177,
#   'title': 'RLS: Release 2.1.4',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 131473665,
#     'node_id': 'MDU6TGFiZWwxMzE0NzM2NjU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Release',
#     'name': 'Release',
#     'color': '006b75',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/113',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/113',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/113/labels',
#    'id': 10178781,
#    'node_id': 'MI_kwDOAA0YD84Am1Dd',
#    'number': 113,
#    'title': '2.1.4',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'jorisvandenbossche',
#     'id': 1020496,
#     'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jorisvandenbossche',
#     'html_url': 'https://github.com/jorisvandenbossche',
#     'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#     'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#     'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#     'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 28,
#    'closed_issues': 25,
#    'state': 'open',
#    'created_at': '2023-11-13T10:53:23Z',
#    'updated_at': '2023-11-27T14:25:58Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-11-26T17:10:20Z',
#   'updated_at': '2023-11-26T17:10:20Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Release Date: TBD (tentatively scheduled for December 6, 2023)',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56177/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56177/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56175',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56175/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56175/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56175/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56175',
#   'id': 2010847581,
#   'node_id': 'PR_kwDOAA0YD85gXYlX',
#   'number': 56175,
#   'title': 'ENH: Allow dictionaries to be passed to pandas.Series.str.replace',
#   'user': {'login': 'rmhowe425',
#    'id': 45905457,
#    'node_id': 'MDQ6VXNlcjQ1OTA1NDU3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45905457?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rmhowe425',
#    'html_url': 'https://github.com/rmhowe425',
#    'followers_url': 'https://api.github.com/users/rmhowe425/followers',
#    'following_url': 'https://api.github.com/users/rmhowe425/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rmhowe425/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rmhowe425/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rmhowe425/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rmhowe425/orgs',
#    'repos_url': 'https://api.github.com/users/rmhowe425/repos',
#    'events_url': 'https://api.github.com/users/rmhowe425/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rmhowe425/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-26T01:04:22Z',
#   'updated_at': '2023-11-26T18:20:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56175',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56175',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56175.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56175.patch',
#    'merged_at': None},
#   'body': '- [X] closes #51748 \r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [X] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56175/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56175/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56174',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56174/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56174/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56174/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/56174',
#   'id': 2010835640,
#   'node_id': 'PR_kwDOAA0YD85gXWSA',
#   'number': 56174,
#   'title': 'CI: Add 3.12 builds',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-11-26T00:08:56Z',
#   'updated_at': '2023-11-26T13:17:10Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/56174',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/56174',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/56174.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/56174.patch',
#    'merged_at': None},
#   'body': 'Some CoW warnings broke for 3.11, so we should test at least CoW for 3.12 as well',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56174/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56174/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/56221',
#  'id': 2014356123,
#  'node_id': 'I_kwDOAA0YD854EKKb',
#  'number': 56221,
#  'title': "BUG: `pd.nlargest` with `keep='all'` does not return the correct result",
#  'user': {'login': 'psads-git',
#   'id': 75945439,
#   'node_id': 'MDQ6VXNlcjc1OTQ1NDM5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/75945439?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/psads-git',
#   'html_url': 'https://github.com/psads-git',
#   'followers_url': 'https://api.github.com/users/psads-git/followers',
#   'following_url': 'https://api.github.com/users/psads-git/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/psads-git/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/psads-git/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/psads-git/subscriptions',
#   'organizations_url': 'https://api.github.com/users/psads-git/orgs',
#   'repos_url': 'https://api.github.com/users/psads-git/repos',
#   'events_url': 'https://api.github.com/users/psads-git/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/psads-git/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [{'id': 76811,
#    'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#    'name': 'Bug',
#    'color': 'e10c02',
#    'default': False,
#    'description': None},
#   {'id': 1954720290,
#    'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#    'name': 'Needs Triage',
#    'color': '0052cc',
#    'default': False,
#    'description': 'Issue that has not been reviewed by a pandas team member'}],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 0,
#  'created_at': '2023-11-28T12:43:12Z',
#  'updated_at': '2023-11-28T12:46:17Z',
#  'closed_at': None,
#  'author_association': 'NONE',
#  'active_lock_reason': None,
#  'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\ntechnologies =  "A B C D E F G H I J".split()\r\nduration     = [88,70,50,87,77,88,77,88,1,87]\r\ncolumns      = [\'technologies\',\'duration\']\r\ndf = pd.DataFrame(list(zip(technologies,duration)), columns=columns)\r\ndf.nlargest(3, \'duration\', keep=\'all\')\n```\n\n\n### Issue Description\n\nAccording to the example that uses `keep=\'all\'`, the 3 top values and their duplicates should show up in the result, but only the value `88` is returned.\n\n### Expected Behavior\n\n```\r\n  technologies  duration\r\n0            A        88\r\n5            F        88\r\n7            H        88\r\n3            D        87\r\n9            J        87\r\n4            E        77\r\n6            G        77\r\n\r\n```\n\n### Installed Versions\n\n/home/x/myenv/lib64/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : 2a953cf80b77e4348bf50ed724f8abc0d814d9dd\r\npython              : 3.11.6.final.0\r\npython-bits         : 64\r\nOS                  : Linux\r\nOS-release          : 6.5.12-300.fc39.x86_64\r\nVersion             : #1 SMP PREEMPT_DYNAMIC Mon Nov 20 22:44:24 UTC 2023\r\nmachine             : x86_64\r\nprocessor           : \r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : en_US.utf8\r\nLOCALE              : en_US.UTF-8\r\n\r\npandas              : 2.1.3\r\nnumpy               : 1.26.2\r\npytz                : 2023.3.post1\r\ndateutil            : 2.8.2\r\nsetuptools          : 69.0.2\r\npip                 : 23.3.1\r\nCython              : 3.0.6\r\npytest              : None\r\nhypothesis          : None\r\nsphinx              : None\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : None\r\nlxml.etree          : 4.9.3\r\nhtml5lib            : 1.1\r\npymysql             : None\r\npsycopg2            : None\r\njinja2              : 3.1.2\r\nIPython             : 8.18.1\r\npandas_datareader   : None\r\nbs4                 : 4.12.2\r\nbottleneck          : None\r\ndataframe-api-compat: None\r\nfastparquet         : None\r\nfsspec              : 2023.10.0\r\ngcsfs               : None\r\nmatplotlib          : 3.8.2\r\nnumba               : 0.58.1\r\nnumexpr             : None\r\nodfpy               : None\r\nopenpyxl            : 3.1.2\r\npandas_gbq          : None\r\npyarrow             : None\r\npyreadstat          : None\r\npyxlsb              : None\r\ns3fs                : None\r\nscipy               : 1.11.4\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : None\r\nxarray              : None\r\nxlrd                : None\r\nzstandard           : None\r\ntzdata              : 2023.3\r\nqtpy                : None\r\npyqt5               : None\r\n',
#  'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56221/timeline',
#  'performed_via_github_app': None,
#  'state_reason': None}

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 75945439
# 61934744
# 122238526
# 47032563
# 8078968
# 61934744
# 61934744
# 91160475
# 61934744
# 61934744
# 10647082
# 61934744
# 49510873
# 23026498
# 33491632
# 122238526
# 10647082
# 61934744
# 61934744
# 61934744
# 61934744
# 61934744
# 61934744
# 10647082
# 61934744
# 61934744
# 61934744
# 47963215
# 45905457
# 61934744

# %%
pd.DataFrame(data1,columns=['id','url','repository_url','labels_url'])
# Out:
#             id                                                url  \
# 0   2014356123  https://api.github.com/repos/pandas-dev/pandas...
# 1   2014261711  https://api.github.com/repos/pandas-dev/pandas...
# 2   2013776658  https://api.github.com/repos/pandas-dev/pandas...
# 3   2013667137  https://api.github.com/repos/pandas-dev/pandas...
# 4   2013367045  https://api.github.com/repos/pandas-dev/pandas...
# 5   2013338895  https://api.github.com/repos/pandas-dev/pandas...
# 6   2013308111  https://api.github.com/repos/pandas-dev/pandas...
# 7   2013226081  https://api.github.com/repos/pandas-dev/pandas...
# 8   2013180700  https://api.github.com/repos/pandas-dev/pandas...
# 9   2013152202  https://api.github.com/repos/pandas-dev/pandas...
# 10  2013018133  https://api.github.com/repos/pandas-dev/pandas...
# 11  2013017507  https://api.github.com/repos/pandas-dev/pandas...
# 12  2012791558  https://api.github.com/repos/pandas-dev/pandas...
# 13  2012043795  https://api.github.com/repos/pandas-dev/pandas...
# 14  2011950897  https://api.github.com/repos/pandas-dev/pandas...
# 15  2011416854  https://api.github.com/repos/pandas-dev/pandas...
# 16  2011394639  https://api.github.com/repos/pandas-dev/pandas...
# 17  2011264070  https://api.github.com/repos/pandas-dev/pandas...
# 18  2011215972  https://api.github.com/repos/pandas-dev/pandas...
# 19  2011207750  https://api.github.com/repos/pandas-dev/pandas...
# 20  2011194283  https://api.github.com/repos/pandas-dev/pandas...
# 21  2011187087  https://api.github.com/repos/pandas-dev/pandas...
# 22  2011186941  https://api.github.com/repos/pandas-dev/pandas...
# 23  2011177422  https://api.github.com/repos/pandas-dev/pandas...
# 24  2011140992  https://api.github.com/repos/pandas-dev/pandas...
# 25  2011139111  https://api.github.com/repos/pandas-dev/pandas...
# 26  2011126080  https://api.github.com/repos/pandas-dev/pandas...
# 27  2011121307  https://api.github.com/repos/pandas-dev/pandas...
# 28  2010847581  https://api.github.com/repos/pandas-dev/pandas...
# 29  2010835640  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
